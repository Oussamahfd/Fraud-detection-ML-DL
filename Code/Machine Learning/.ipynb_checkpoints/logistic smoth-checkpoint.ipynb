# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

# %%
start_time = time.time()
df_train = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTrain.csv')

# %%
start_time = time.time()
df_test = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTest.csv')

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Créer une copie de df_train pour les transformations
df_corr = df_train.copy()

# Instantiate the LabelEncoder
encoder = LabelEncoder()

# Appliquer les transformations sur df_corr sans modifier df_train
df_corr["category"] = encoder.fit_transform(df_corr["category"])
df_corr["gender"] = encoder.fit_transform(df_corr["gender"])
df_corr["city"] = encoder.fit_transform(df_corr["city"])
df_corr["state"] = encoder.fit_transform(df_corr["state"])
df_corr["job"] = encoder.fit_transform(df_corr["job"])

# %%
df_train .drop(columns=['Unnamed: 0','merchant', 'cc_num','first', 'last','gender','trans_num','unix_time','street','merch_lat','merch_long','job','zip'], inplace= True)

# %%
# convert all dtype in float
df_train ['trans_date_trans_time'] = pd.to_datetime(df_train['trans_date_trans_time'])
df_train ['trans_date_trans_time'] = df_train ['trans_date_trans_time'].apply(lambda x: x.timestamp())
df_train ['dob'] = pd.to_datetime(df_train ['dob'])
df_train ['dob'] = df_train ['dob'].apply(lambda x: x.timestamp())
label_encoder = LabelEncoder()
columns_to_convert_in_string_to_int = ['category','city', 'state']
for col in columns_to_convert_in_string_to_int:
    df_train [col] = label_encoder.fit_transform(df_train [col])
columns_to_convert_in_int_to_float = ['category','city', 'state','city_pop']
for col in columns_to_convert_in_int_to_float:
    df_train [col] = df_train [col].astype('float64')

# %%
X = df_train .drop(columns=['is_fraud'])
Y = df_train ['is_fraud']

# %%
scaler = StandardScaler()
X= scaler.fit_transform(X)

# %%
X_train, _ , Y_train, _ = train_test_split(X, Y, random_state=42)

# %%
# drop unnecessary columns
df_test .drop(columns=['Unnamed: 0','merchant', 'cc_num','first', 'last','gender','trans_num','unix_time','street','merch_lat','merch_long','job','zip'], inplace= True)
# Out:
#        trans_date_trans_time        category     amt          city state  \
# 0        2020-06-21 12:14:25   personal_care    2.86      Columbia    SC
# 1        2020-06-21 12:14:33   personal_care   29.84       Altonah    UT
# 2        2020-06-21 12:14:53  health_fitness   41.28      Bellmore    NY
# 3        2020-06-21 12:15:15        misc_pos   60.05    Titusville    FL
# 4        2020-06-21 12:15:17          travel    3.19      Falmouth    MI
# ...                      ...             ...     ...           ...   ...
# 555714   2020-12-31 23:59:07  health_fitness   43.77         Luray    MO
# 555715   2020-12-31 23:59:09       kids_pets  111.84  Lake Jackson    TX
# 555716   2020-12-31 23:59:15       kids_pets   86.88       Burbank    WA
# 555717   2020-12-31 23:59:24          travel    7.99          Mesa    ID
# 555718   2020-12-31 23:59:34   entertainment   38.13        Edmond    OK
#
#             lat      long  city_pop         dob  is_fraud
# 0       33.9659  -80.9355    333497  1968-03-19         0
# 1       40.3207 -110.4360       302  1990-01-17         0
# 2       40.6729  -73.5365     34496  1970-10-21         0
# 3       28.5697  -80.8191     54767  1987-07-25         0
# 4       44.2529  -85.0170      1126  1955-07-06         0
# ...         ...       ...       ...         ...       ...
# 555714  40.4931  -91.8912       519  1966-02-13         0
# 555715  29.0393  -95.4401     28739  1999-12-27         0
# 555716  46.1966 -118.9017      3684  1981-11-29         0
# 555717  44.6255 -116.4493       129  1965-12-15         0
# 555718  35.6665  -97.4798    116001  1993-05-10         0
#
# [555719 rows x 10 columns]

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_smote)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
model = LogisticRegression(max_iter=1000, random_state=42)

# %%
model.fit(X_train_scaled, Y_train_smote)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_train_pred = model.predict(X_train_scaled)

# %%
print(f"Accuracy: {accuracy_score(Y_train_smote, y_train_pred)}")
print(classification_report(Y_train_smote, y_train_pred))
# Out:
# Accuracy: 0.8550637925542257
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87    966884
#            1       0.94      0.76      0.84    966884
#
#     accuracy                           0.86   1933768
#    macro avg       0.87      0.86      0.85   1933768
# weighted avg       0.87      0.86      0.85   1933768

# %%
# Appliquer SMOTE pour suréchantillonner la classe minoritaire
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Afficher le nombre de transactions frauduleuses et non frauduleuses après SMOTE
print("Nombre de transactions non frauduleuses après SMOTE :", (Y_train_smote == 0).sum())
print("Nombre de transactions frauduleuses après SMOTE :", (Y_train_smote == 1).sum())
# Out:
# Nombre de transactions non frauduleuses après SMOTE : 966884
# Nombre de transactions frauduleuses après SMOTE : 966884

# %%
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Charger les données
start_time = time.time()
df_train = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTrain.csv')
df_test = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTest.csv')

# Prétraitement des données
# Supprimer les colonnes inutiles
df_train.drop(columns=['Unnamed: 0', 'merchant', 'cc_num', 'first', 'last', 'gender', 'trans_num', 'unix_time', 'street', 'merch_lat', 'merch_long', 'job', 'zip'], inplace=True)
df_test.drop(columns=['Unnamed: 0', 'merchant', 'cc_num', 'first', 'last', 'gender', 'trans_num', 'unix_time', 'street', 'merch_lat', 'merch_long', 'job', 'zip'], inplace=True)

# Convertir les dates en timestamps
df_train['trans_date_trans_time'] = pd.to_datetime(df_train['trans_date_trans_time']).apply(lambda x: x.timestamp())
df_train['dob'] = pd.to_datetime(df_train['dob']).apply(lambda x: x.timestamp())

df_test['trans_date_trans_time'] = pd.to_datetime(df_test['trans_date_trans_time']).apply(lambda x: x.timestamp())
df_test['dob'] = pd.to_datetime(df_test['dob']).apply(lambda x: x.timestamp())

# Encodage des colonnes catégoriques
label_encoder = LabelEncoder()
columns_to_convert_in_string_to_int = ['category', 'city', 'state']
for col in columns_to_convert_in_string_to_int:
    df_train[col] = label_encoder.fit_transform(df_train[col])
    df_test[col] = label_encoder.transform(df_test[col])  # Utiliser le même encodage pour df_test

# Convertir les colonnes en float
columns_to_convert_in_int_to_float = ['category', 'city', 'state', 'city_pop']
for col in columns_to_convert_in_int_to_float:
    df_train[col] = df_train[col].astype('float64')
    df_test[col] = df_test[col].astype('float64')

# Séparer les caractéristiques et la variable cible
X_train = df_train.drop(columns=['is_fraud'])
Y_train = df_train['is_fraud']
X_test = df_test.drop(columns=['is_fraud'])
Y_test = df_test['is_fraud']

# Normaliser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Suréchantillonnage avec SMOTE
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Créer et entraîner le modèle de régression logistique
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_smote, Y_train_smote)

# Prédiction sur df_test
y_pred = model.predict(X_test)

# Évaluation du modèle
print("Accuracy:", accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 'Springville'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 31
#      29 for col in columns_to_convert_in_string_to_int:
#      30     df_train[col] = label_encoder.fit_transform(df_train[col])
# ---> 31     df_test[col] = label_encoder.transform(df_test[col])  # Utiliser le même encodage pour df_test
#      33 # Convertir les colonnes en float
#      34 columns_to_convert_in_int_to_float = ['category', 'city', 'state', 'city_pop']
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'Springville'

# %%
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Charger les données
start_time = time.time()
df_train = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTrain.csv')
df_test = pd.read_csv('C:/Users/PC/Desktop/2/pfa/Datasets/Credit Card Transactions Fraud Detection Dataset/fraudTest.csv')

# Prétraitement des données
# Supprimer les colonnes inutiles
df_train.drop(columns=['Unnamed: 0', 'merchant', 'cc_num', 'first', 'last', 'gender', 'trans_num', 'unix_time', 'street', 'merch_lat', 'merch_long', 'job', 'zip'], inplace=True)
df_test.drop(columns=['Unnamed: 0', 'merchant', 'cc_num', 'first', 'last', 'gender', 'trans_num', 'unix_time', 'street', 'merch_lat', 'merch_long', 'job', 'zip'], inplace=True)

# Convertir les dates en timestamps
df_train['trans_date_trans_time'] = pd.to_datetime(df_train['trans_date_trans_time']).apply(lambda x: x.timestamp())
df_train['dob'] = pd.to_datetime(df_train['dob']).apply(lambda x: x.timestamp())

df_test['trans_date_trans_time'] = pd.to_datetime(df_test['trans_date_trans_time']).apply(lambda x: x.timestamp())
df_test['dob'] = pd.to_datetime(df_test['dob']).apply(lambda x: x.timestamp())

# Encodage des colonnes catégoriques
label_encoder = LabelEncoder()
columns_to_convert_in_string_to_int = ['category', 'city', 'state']

# Entraîner l'encodeur sur df_train et transformer df_train
for col in columns_to_convert_in_string_to_int:
    df_train[col] = label_encoder.fit_transform(df_train[col])
    
# Transformer df_test en utilisant les classes de df_train
for col in columns_to_convert_in_string_to_int:
    # Utiliser les mêmes classes que celles de df_train pour df_test
    df_test[col] = df_test[col].map(lambda x: label_encoder.transform([x])[0] if x in label_encoder.classes_ else -1)

# Convertir les colonnes en float
columns_to_convert_in_int_to_float = ['category', 'city', 'state', 'city_pop']
for col in columns_to_convert_in_int_to_float:
    df_train[col] = df_train[col].astype('float64')
    df_test[col] = df_test[col].astype('float64')

# Séparer les caractéristiques et la variable cible
X_train = df_train.drop(columns=['is_fraud'])
Y_train = df_train['is_fraud']
X_test = df_test.drop(columns=['is_fraud'])
Y_test = df_test['is_fraud']

# Normaliser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Suréchantillonnage avec SMOTE
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Créer et entraîner le modèle de régression logistique
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_smote, Y_train_smote)

# Prédiction sur df_test
y_pred = model.predict(X_test)

# Évaluation du modèle
print("Accuracy:", accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy: 0.9020062297672025
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95    553574
#            1       0.03      0.75      0.06      2145
#
#     accuracy                           0.90    555719
#    macro avg       0.51      0.83      0.50    555719
# weighted avg       1.00      0.90      0.94    555719

# %%
# Afficher le nombre de transactions frauduleuses et non frauduleuses avant SMOTE
print("Nombre de transactions frauduleuses avant SMOTE :", Y_train.sum())
print("Nombre de transactions non frauduleuses avant SMOTE :", len(Y_train) - Y_train.sum())
# Afficher le nombre de transactions frauduleuses et non frauduleuses après SMOTE
print("Nombre de transactions frauduleuses après SMOTE :", Y_train_smote.sum())
print("Nombre de transactions non frauduleuses après SMOTE :", len(Y_train_smote) - Y_train_smote.sum())
# Out:
# Nombre de transactions frauduleuses avant SMOTE : 7506
# Nombre de transactions non frauduleuses avant SMOTE : 1289169
# Nombre de transactions frauduleuses après SMOTE : 1289169
# Nombre de transactions non frauduleuses après SMOTE : 1289169
